# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from sklearn import decomposition
from sklearn import datasets

# %%
dtiris = datasets.load_iris(False)
fig = plt.figure(figsize=(15,5))
ax = axes3d.Axes3D(fig)
x_lower = decomposition.PCA(n_components=4).fit_transform(dtiris.data)
ax.scatter(x_lower[:, 0], x_lower[:, 1], x_lower[:, 2], c=y)
ax.set_title("Iris data 3D view")
ax.set_xlabel("Setosa")
ax.set_ylabel("Versicolor")
ax.set_zlabel("Virginica")
plt.show()
